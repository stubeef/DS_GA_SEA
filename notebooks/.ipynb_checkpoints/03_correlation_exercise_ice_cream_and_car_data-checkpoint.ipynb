# %% [markdown]
# # General Assembly Data Science Seattle

# %% [markdown]
# ## Lesson 3: Correlation exercise with ice cream consumption and car data

# %%
#General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# * [View the list of standard R datasets](https://vincentarelbundock.github.io/Rdatasets/datasets.html)
# * [View the ice cream consumption data set data dictionary](https://vincentarelbundock.github.io/Rdatasets/doc/Ecdat/Icecream.html)

# %%
# read the ice cream data from icecream.csv into a DataFrame named "Ice"
url = 'https://github.com/JamesByers/GA-SEA-DAT2/raw/master/data/icecream.csv' 
ice = pd.read_csv(url, index_col=0)

# %%
# display the number of rows and columns
ice.shape
# Out:
# (30, 4)

# %%
ice.head(10)
# Out:
#      cons  income  price  temp
# 1   0.386      78  0.270    41
# 2   0.374      79  0.282    56
# 3   0.393      81  0.277    63
# 4   0.425      80  0.280    68
# 5   0.406      76  0.272    69
# 6   0.344      78  0.262    65
# 7   0.327      82  0.275    61
# 8   0.288      79  0.267    47
# 9   0.269      76  0.265    32
# 10  0.256      79  0.277    24

# %%
# display the whole data frame to the screen
ice
# Out:
#      cons  income  price  temp
# 1   0.386      78  0.270    41
# 2   0.374      79  0.282    56
# 3   0.393      81  0.277    63
# 4   0.425      80  0.280    68
# 5   0.406      76  0.272    69
# 6   0.344      78  0.262    65
# 7   0.327      82  0.275    61
# 8   0.288      79  0.267    47
# 9   0.269      76  0.265    32
# 10  0.256      79  0.277    24
# 11  0.286      82  0.282    28
# 12  0.298      85  0.270    26
# 13  0.329      86  0.272    32
# 14  0.318      83  0.287    40
# 15  0.381      84  0.277    55
# 16  0.381      82  0.287    63
# 17  0.470      80  0.280    72
# 18  0.443      78  0.277    72
# 19  0.386      84  0.277    67
# 20  0.342      86  0.277    60
# 21  0.319      85  0.292    44
# 22  0.307      87  0.287    40
# 23  0.284      94  0.277    32
# 24  0.326      92  0.285    27
# 25  0.309      95  0.282    28
# 26  0.359      96  0.265    33
# 27  0.376      94  0.265    41
# 28  0.416      96  0.265    52
# 29  0.437      91  0.268    64
# 30  0.548      90  0.260    71

# %%
# display a scatter plot of temp vs. consumption
ice.plot(kind='scatter', x='temp', y='cons')

# %% [markdown]
# Is the above data correlated? <br></br>
# Answer:Yes

# %%
ice.corrwith(ice["temp"])
# Out:
# cons      0.775625
# income   -0.324709
# price    -0.108206
# temp      1.000000
# dtype: float64

# %%
# scatter matrix of three numerical columns
pd.scatter_matrix(ice[['cons', 'income', 'price', 'temp'] ])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C53FC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CB9D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C76F198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC21940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CBD4A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AE6B588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CCC1F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CDFC7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CEC83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CF7FB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D08D630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D16CF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D20ED30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D1D5048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D44D208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D54CA90>]], dtype=object)

# %%
# Display a correlation matrix of the ice dataframe
ice.corr()
# Out:
#             cons    income     price      temp
# cons    1.000000  0.047935 -0.259594  0.775625
# income  0.047935  1.000000 -0.107479 -0.324709
# price  -0.259594 -0.107479  1.000000 -0.108206
# temp    0.775625 -0.324709 -0.108206  1.000000

# %%
# Display a histogram of temperature
ice.temp.plot(kind='hist')

# %%
ice.hist("temp")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D736A58>]], dtype=object)

# %%
# Create a density plot of temperature
ice.temp.plot(kind='density')

# %%
ice.temp.plot.density()

# %%
# create a box plot of temperature
ice.temp.plot(kind='box')

# %%
# display the main statistical metrics of the ice dataframe
ice.describe()
# Out:
#             cons    income      price       temp
# count  30.000000  30.00000  30.000000  30.000000
# mean    0.359433  84.60000   0.275300  49.100000
# std     0.065791   6.24555   0.008342  16.421916
# min     0.256000  76.00000   0.260000  24.000000
# 25%     0.311250  79.25000   0.268500  32.250000
# 50%     0.351500  83.50000   0.277000  49.500000
# 75%     0.391250  89.25000   0.281500  63.750000
# max     0.548000  96.00000   0.292000  72.000000

# %% [markdown]
# ***

# %% [markdown]
# ## Independent practice with the Motor Trend Car Road Tests dataset

# %% [markdown]
# * [View the Car Road Tests dataset data dictionary](https://vincentarelbundock.github.io/Rdatasets/doc/datasets/mtcars.html)

# %%
# the link to the data in a csv file is: https://github.com/JamesByers/GA-SEA-DAT2/raw/master/data/mtcars.csv
# read the ice cream data into a DataFrame named "cars"
url2 = "https://github.com/JamesByers/GA-SEA-DAT2/raw/master/data/mtcars.csv"
cars = pd.read_csv(url2,index_col=0)

# %% [markdown]
# Add some cells and evaluate the dataset by displaying some rows of the dataset, displaying the data types, and displaying the number of rows and columns and the main statistical metrics.

# %%
cars.shape
cars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
# create a scatter matrix of the numeric variables mpg, disp, hp, wt, qsec
pd.scatter_matrix(cars[["mpg","disp",'hp','wt','qsec']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010A3ADA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010D791D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010DB1BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010EAA400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010F65EB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000FA17390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011118F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000111CE780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011299588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000112528D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001145EA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001156F2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011613E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000117237B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000117E8E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000118B5898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001199EF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011AADB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011B63390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011C1DFD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011B77E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011DE2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011E18B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011F9A940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012067208>]], dtype=object)

# %%
# create a correlation matrix of the dataframe
cars.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# mpg   0.664039  0.599832  0.480285 -0.550925
# cyl  -0.810812 -0.522607 -0.492687  0.526988
# disp -0.710416 -0.591227 -0.555569  0.394977
# hp   -0.723097 -0.243204 -0.125704  0.749812
# drat  0.440278  0.712711  0.699610 -0.090790
# wt   -0.554916 -0.692495 -0.583287  0.427606
# qsec  0.744535 -0.229861 -0.212682 -0.656249
# vs    1.000000  0.168345  0.206023 -0.569607
# am    0.168345  1.000000  0.794059  0.057534
# gear  0.206023  0.794059  1.000000  0.274073
# carb -0.569607  0.057534  0.274073  1.000000

# %% [markdown]
# Describe in words one positive and one strong negative correlation
# Answer:

# %%
# create a single scattergram of a pair of variables with a high positive or negative correlation
cars.plot(kind='scatter', x='disp', y='mpg')

# %% [markdown]
# In the cells below create at least 3 graphs of different types using any combination of variables.  Search for "Pandas plot" to find the documentation page that shows allowed values of the parameter "kind"

# %%
cars.disp.plot(kind="box")

# %%
cars.plot(kind="pie", y="cyl")

# %%
cars.plot(kind="hist", y="cyl")

# %% [markdown]
# ### Bonus:  create a chart with multiple boxplots on one graph
# Hint: Look at the single boxplot code for ice cream and think about how you would make it less specific

# %%
cars[["disp","hp"]].plot(kind="box")

# %% [markdown]
# ### Bonus: show a chart with just boxplots for disp and hp
# Hint: check out the "Selection" section of the 02_numpy_and_pandas notebook in the class repository
